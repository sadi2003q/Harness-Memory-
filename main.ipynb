# %%
from brain import Brain
from agent import Agent
from tracer import Tracer
from tools import ALL_TOOLS
from memory.memory_manager import MemoryManager

brain = Brain(TOKEN)
memory = MemoryManager()
tracer = Tracer()
agent = Agent(brain, memory, ALL_TOOLS, tracer)

# %%
memory.semantic.add_fact("The user's favourite colour is blue.")
print(agent.ask("What is 25 * 4?"))
print(agent.ask("What is my favourite colour?"))
print(agent.ask("Schedule a meeting: Team sync | Monday 10am"))

# %%
memory.semantic.add_fact("The user's favorite color is teal.")
print(agent.ask("What is my favorite color?"))
